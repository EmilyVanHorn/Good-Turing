# %%
import pandas as pd
from scipy import stats

# %%
data = pd.read_csv("/Users/jchan/Projects/Good-Turing/Data Output/NEWParamSearch_Experiment.csv")

# %%
data.head()
# Out:
#        dataset     method  timeSlice  GT_predict  TRUE
# 0  SuperBoring  nltk_0.20          1        1.00  1.00
# 1  SuperBoring  nltk_0.20          2        0.87  0.75
# 2  SuperBoring  nltk_0.20          3        0.73  0.71
# 3  SuperBoring  nltk_0.20          4        0.71  0.85
# 4  SuperBoring  nltk_0.20          5        0.47  0.65

# %% [markdown]
# For each run, calculate:
# 1. The degree to which the GT estimate matches the true frequency of new ideas in a given time slice (using a correlation)
# 2. The OLS slope for timeslice as a rough estimate of how much the predicted frequency of new ideas declines with time

# %%
evaluation = []
for dataset, dataset_data in data.groupby("dataset"):
    for method, method_data in dataset_data.groupby("method"):
        # correlation with the TRUE
        print dataset, method
        corr_true = stats.linregress(method_data['GT_predict'], method_data['TRUE'])[2]
        # slope
        decline_slope = stats.linregress(method_data['timeSlice'], method_data['GT_predict'])[0]
        print "Correlation with \"TRUE\": ", corr_true
        print "Slope of the decline: ", decline_slope
        evaluation.append({'dataset': dataset, 
                           'method': method.split("_")[0], 
                           'threshold': method.split("_")[1], 
                           'run': method,
                           'corr_true': corr_true,
                           'decline_slope': decline_slope})
evaluation = pd.DataFrame(evaluation)
evaluation
# Out:
# Boring nltk_0.20
# Correlation with "TRUE":  0.780601012252
# Slope of the decline:  -0.0112371541502
# Boring nltk_0.40
# Correlation with "TRUE":  0.745056074441
# Slope of the decline:  -0.0104664031621
# Boring nltk_0.60
# Correlation with "TRUE":  0.747353943922
# Slope of the decline:  -0.00966403162055
# Boring nltk_0.80
# Correlation with "TRUE":  0.747353943922
# Slope of the decline:  -0.00966403162055
# Boring word2vec_0.20
# Correlation with "TRUE":  0.265398731373
# Slope of the decline:  -0.000285902503294
# Boring word2vec_0.40
# Correlation with "TRUE":  0.55911736685
# Slope of the decline:  -0.00312911725955
# Boring word2vec_0.60
# Correlation with "TRUE":  0.768067490583
# Slope of the decline:  -0.00841765480896
# Boring word2vec_0.80
# Correlation with "TRUE":  0.73593108521
# Slope of the decline:  -0.00926613965744
# Exciting nltk_0.20
# Correlation with "TRUE":  0.878335405378
# Slope of the decline:  -0.0126060606061
# Exciting nltk_0.40
# Correlation with "TRUE":  0.824387389218
# Slope of the decline:  -0.0126534914361
# Exciting nltk_0.60
# Correlation with "TRUE":  0.820139551059
# Slope of the decline:  -0.011768115942
# Exciting nltk_0.80
# Correlation with "TRUE":  0.820139551059
# Slope of the decline:  -0.011768115942
# Exciting word2vec_0.20
# Correlation with "TRUE":  0.691770571595
# Slope of the decline:  -0.00153096179183
# Exciting word2vec_0.40
# Correlation with "TRUE":  0.826027545337
# Slope of the decline:  -0.00443214756258
# Exciting word2vec_0.60
# Correlation with "TRUE":  0.877400999291
# Slope of the decline:  -0.010628458498
# Exciting word2vec_0.80
# Correlation with "TRUE":  0.831318073622
# Slope of the decline:  -0.0119288537549
# NewAtEnd nltk_0.20
# Correlation with "TRUE":  0.655872083445
# Slope of the decline:  -0.00888669301713
# NewAtEnd nltk_0.40
# Correlation with "TRUE":  0.534319190255
# Slope of the decline:  -0.00800658761528
# NewAtEnd nltk_0.60
# Correlation with "TRUE":  0.545937901372
# Slope of the decline:  -0.00842687747036
# NewAtEnd nltk_0.80
# Correlation with "TRUE":  0.545937901372
# Slope of the decline:  -0.00842687747036
# NewAtEnd word2vec_0.20
# Correlation with "TRUE":  0.520048262718
# Slope of the decline:  -0.000399209486166
# NewAtEnd word2vec_0.40
# Correlation with "TRUE":  0.717803333497
# Slope of the decline:  -0.00395256916996
# NewAtEnd word2vec_0.60
# Correlation with "TRUE":  0.650549604701
# Slope of the decline:  -0.00795388669302
# NewAtEnd word2vec_0.80
# Correlation with "TRUE":  0.504343114793
# Slope of the decline:  -0.00798945981555
# Normal nltk_0.20
# Correlation with "TRUE":  0.775512457282
# Slope of the decline:  -0.0134400527009
# Normal nltk_0.40
# Correlation with "TRUE":  0.70018789537
# Slope of the decline:  -0.0123965744401
# Normal nltk_0.60
# Correlation with "TRUE":  0.723354963509
# Slope of the decline:  -0.0125204216074
# Normal nltk_0.80
# Correlation with "TRUE":  0.723354963509
# Slope of the decline:  -0.0125204216074
# Normal word2vec_0.20
# Correlation with "TRUE":  0.0892171603884
# Slope of the decline:  -0.000503293807642
# Normal word2vec_0.40
# Correlation with "TRUE":  0.4555780352
# Slope of the decline:  -0.00376021080369
# Normal word2vec_0.60
# Correlation with "TRUE":  0.652680112835
# Slope of the decline:  -0.00950197628458
# Normal word2vec_0.80
# Correlation with "TRUE":  0.698651973568
# Slope of the decline:  -0.0116455862978
# SuperBoring nltk_0.20
# Correlation with "TRUE":  0.891259969649
# Slope of the decline:  -0.0111225296443
# SuperBoring nltk_0.40
# Correlation with "TRUE":  0.86126283073
# Slope of the decline:  -0.0103214756258
# SuperBoring nltk_0.60
# Correlation with "TRUE":  0.875023141796
# Slope of the decline:  -0.0106666666667
# SuperBoring nltk_0.80
# Correlation with "TRUE":  0.875023141796
# Slope of the decline:  -0.0106666666667
# SuperBoring word2vec_0.20
# Correlation with "TRUE":  0.592386624797
# Slope of the decline:  -0.00153227931489
# SuperBoring word2vec_0.40
# Correlation with "TRUE":  0.769541346615
# Slope of the decline:  -0.00281686429513
# SuperBoring word2vec_0.60
# Correlation with "TRUE":  0.831387092044
# Slope of the decline:  -0.00763241106719
# SuperBoring word2vec_0.80
# Correlation with "TRUE":  0.874216219759
# Slope of the decline:  -0.0104466403162
#     corr_true      dataset  decline_slope    method            run threshold
# 0    0.780601       Boring      -0.011237      nltk      nltk_0.20      0.20
# 1    0.745056       Boring      -0.010466      nltk      nltk_0.40      0.40
# 2    0.747354       Boring      -0.009664      nltk      nltk_0.60      0.60
# 3    0.747354       Boring      -0.009664      nltk      nltk_0.80      0.80
# 4    0.265399       Boring      -0.000286  word2vec  word2vec_0.20      0.20
# 5    0.559117       Boring      -0.003129  word2vec  word2vec_0.40      0.40
# 6    0.768067       Boring      -0.008418  word2vec  word2vec_0.60      0.60
# 7    0.735931       Boring      -0.009266  word2vec  word2vec_0.80      0.80
# 8    0.878335     Exciting      -0.012606      nltk      nltk_0.20      0.20
# 9    0.824387     Exciting      -0.012653      nltk      nltk_0.40      0.40
# 10   0.820140     Exciting      -0.011768      nltk      nltk_0.60      0.60
# 11   0.820140     Exciting      -0.011768      nltk      nltk_0.80      0.80
# 12   0.691771     Exciting      -0.001531  word2vec  word2vec_0.20      0.20
# 13   0.826028     Exciting      -0.004432  word2vec  word2vec_0.40      0.40
# 14   0.877401     Exciting      -0.010628  word2vec  word2vec_0.60      0.60
# 15   0.831318     Exciting      -0.011929  word2vec  word2vec_0.80      0.80
# 16   0.655872     NewAtEnd      -0.008887      nltk      nltk_0.20      0.20
# 17   0.534319     NewAtEnd      -0.008007      nltk      nltk_0.40      0.40
# 18   0.545938     NewAtEnd      -0.008427      nltk      nltk_0.60      0.60
# 19   0.545938     NewAtEnd      -0.008427      nltk      nltk_0.80      0.80
# 20   0.520048     NewAtEnd      -0.000399  word2vec  word2vec_0.20      0.20
# 21   0.717803     NewAtEnd      -0.003953  word2vec  word2vec_0.40      0.40
# 22   0.650550     NewAtEnd      -0.007954  word2vec  word2vec_0.60      0.60
# 23   0.504343     NewAtEnd      -0.007989  word2vec  word2vec_0.80      0.80
# 24   0.775512       Normal      -0.013440      nltk      nltk_0.20      0.20
# 25   0.700188       Normal      -0.012397      nltk      nltk_0.40      0.40
# 26   0.723355       Normal      -0.012520      nltk      nltk_0.60      0.60
# 27   0.723355       Normal      -0.012520      nltk      nltk_0.80      0.80
# 28   0.089217       Normal      -0.000503  word2vec  word2vec_0.20      0.20
# 29   0.455578       Normal      -0.003760  word2vec  word2vec_0.40      0.40
# 30   0.652680       Normal      -0.009502  word2vec  word2vec_0.60      0.60
# 31   0.698652       Normal      -0.011646  word2vec  word2vec_0.80      0.80
# 32   0.891260  SuperBoring      -0.011123      nltk      nltk_0.20      0.20
# 33   0.861263  SuperBoring      -0.010321      nltk      nltk_0.40      0.40
# 34   0.875023  SuperBoring      -0.010667      nltk      nltk_0.60      0.60
# 35   0.875023  SuperBoring      -0.010667      nltk      nltk_0.80      0.80
# 36   0.592387  SuperBoring      -0.001532  word2vec  word2vec_0.20      0.20
# 37   0.769541  SuperBoring      -0.002817  word2vec  word2vec_0.40      0.40
# 38   0.831387  SuperBoring      -0.007632  word2vec  word2vec_0.60      0.60
# 39   0.874216  SuperBoring      -0.010447  word2vec  word2vec_0.80      0.80

# %%
evaluation.to_csv("Data Output/ParamSearch_Experiment_evaluation.csv")
