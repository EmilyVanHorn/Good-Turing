# %%
import pandas as pd
from scipy import stats
import numpy as np

# %%
data = pd.read_csv("/Users/jchan/Projects/Good-Turing/Data Output/Word2VecOnlyWithStemming.csv")

# %%
sample = data[(data['dataset'] == "Normal") & (data['method'] == "word2vec_0.20")]

# %%
e = stats.expon.fit(sample['GT_predict'], floc=0)
e
# Out:
# (0, 0.021386718749999131)

# %% [markdown]
# For each run, calculate:
# 1. The degree to which the GT estimate matches the true frequency of new ideas in a given time slice (using a correlation)
# 2. The OLS slope for timeslice as a rough estimate of how much the predicted frequency of new ideas declines with time

# %%
evaluation = []
for dataset, dataset_data in data.groupby("dataset"):
    for method, method_data in dataset_data.groupby("method"):
        # correlation with the TRUE
        print dataset, method
        corr_true = stats.linregress(method_data['GT_predict'], method_data['TRUE'])[2]
        # slope
        decline_slope = stats.linregress(method_data['timeSlice'], method_data['GT_predict'])[0]
        print "Correlation with \"TRUE\": ", corr_true
        print "Slope of the decline: ", decline_slope
        evaluation.append({'dataset': dataset, 
                           'method': method.split("_")[0], 
                           'threshold': method.split("_")[1], 
                           'run': method,
                           'corr_true': corr_true,
                           'decline_slope': decline_slope})
evaluation = pd.DataFrame(evaluation)
evaluation
# Out:
# Boring word2vec_0.20
# Correlation with "TRUE":  0.549539554188
# Slope of the decline:  -0.0011163372859
# Boring word2vec_0.30
# Correlation with "TRUE":  0.688932742744
# Slope of the decline:  -0.003030171278
# Boring word2vec_0.40
# Correlation with "TRUE":  0.872242256709
# Slope of the decline:  -0.00625322793149
# Boring word2vec_0.50
# Correlation with "TRUE":  0.773201879344
# Slope of the decline:  -0.00833860342556
# Boring word2vec_0.60
# Correlation with "TRUE":  0.809106280985
# Slope of the decline:  -0.010942687747
# Boring word2vec_0.70
# Correlation with "TRUE":  0.85793192614
# Slope of the decline:  -0.0141358366271
# Boring word2vec_0.80
# Correlation with "TRUE":  0.849933796918
# Slope of the decline:  -0.0132028985507
# Boring word2vec_0.90
# Correlation with "TRUE":  0.830987005029
# Slope of the decline:  -0.012881027668
# Exciting word2vec_0.20
# Correlation with "TRUE":  0.309674552916
# Slope of the decline:  -0.000101844532279
# Exciting word2vec_0.30
# Correlation with "TRUE":  0.389884619598
# Slope of the decline:  -0.00077628458498
# Exciting word2vec_0.40
# Correlation with "TRUE":  0.749868461821
# Slope of the decline:  -0.0031791831357
# Exciting word2vec_0.50
# Correlation with "TRUE":  0.737691847006
# Slope of the decline:  -0.00597061923584
# Exciting word2vec_0.60
# Correlation with "TRUE":  0.821570527201
# Slope of the decline:  -0.00965559947299
# Exciting word2vec_0.70
# Correlation with "TRUE":  0.804055689709
# Slope of the decline:  -0.00953754940711
# Exciting word2vec_0.80
# Correlation with "TRUE":  0.768848689534
# Slope of the decline:  -0.00866337285903
# Exciting word2vec_0.90
# Correlation with "TRUE":  0.744057661536
# Slope of the decline:  -0.00866996047431
# NewAtEnd word2vec_0.20
# Correlation with "TRUE":  0.288768972037
# Slope of the decline:  -0.00019512516469
# NewAtEnd word2vec_0.30
# Correlation with "TRUE":  0.400057159282
# Slope of the decline:  -0.000547826086957
# NewAtEnd word2vec_0.40
# Correlation with "TRUE":  0.580485241541
# Slope of the decline:  -0.00202490118577
# NewAtEnd word2vec_0.50
# Correlation with "TRUE":  0.653408298012
# Slope of the decline:  -0.00442450592885
# NewAtEnd word2vec_0.60
# Correlation with "TRUE":  0.649366443431
# Slope of the decline:  -0.00552898550725
# NewAtEnd word2vec_0.70
# Correlation with "TRUE":  0.531244860705
# Slope of the decline:  -0.0064371541502
# NewAtEnd word2vec_0.80
# Correlation with "TRUE":  0.500878184544
# Slope of the decline:  -0.00630184453228
# NewAtEnd word2vec_0.90
# Correlation with "TRUE":  0.493997298935
# Slope of the decline:  -0.00641712779974
# Normal word2vec_0.20
# Correlation with "TRUE":  0.544288415102
# Slope of the decline:  -0.000116996047431
# Normal word2vec_0.30
# Correlation with "TRUE":  0.675250111548
# Slope of the decline:  -0.00291725955204
# Normal word2vec_0.40
# Correlation with "TRUE":  0.824265416706
# Slope of the decline:  -0.00580606060606
# Normal word2vec_0.50
# Correlation with "TRUE":  0.835769349906
# Slope of the decline:  -0.00774334650856
# Normal word2vec_0.60
# Correlation with "TRUE":  0.895176294389
# Slope of the decline:  -0.0120380764163
# Normal word2vec_0.70
# Correlation with "TRUE":  0.85766951402
# Slope of the decline:  -0.0138383399209
# Normal word2vec_0.80
# Correlation with "TRUE":  0.832478725102
# Slope of the decline:  -0.0124256916996
# Normal word2vec_0.90
# Correlation with "TRUE":  0.801174435762
# Slope of the decline:  -0.0123865612648
# SuperBoring word2vec_0.20
# Correlation with "TRUE":  0.607932059024
# Slope of the decline:  -0.000950197628458
# SuperBoring word2vec_0.30
# Correlation with "TRUE":  0.425119574568
# Slope of the decline:  -0.000676152832675
# SuperBoring word2vec_0.40
# Correlation with "TRUE":  0.773814779258
# Slope of the decline:  -0.00271093544137
# SuperBoring word2vec_0.50
# Correlation with "TRUE":  0.884037927554
# Slope of the decline:  -0.00365638998682
# SuperBoring word2vec_0.60
# Correlation with "TRUE":  0.921278191447
# Slope of the decline:  -0.009269828722
# SuperBoring word2vec_0.70
# Correlation with "TRUE":  0.905125542333
# Slope of the decline:  -0.0109383399209
# SuperBoring word2vec_0.80
# Correlation with "TRUE":  0.872125954316
# Slope of the decline:  -0.0103990777339
# SuperBoring word2vec_0.90
# Correlation with "TRUE":  0.878598890782
# Slope of the decline:  -0.0106797101449
#     corr_true      dataset  decline_slope    method            run threshold
# 0    0.549540       Boring      -0.001116  word2vec  word2vec_0.20      0.20
# 1    0.688933       Boring      -0.003030  word2vec  word2vec_0.30      0.30
# 2    0.872242       Boring      -0.006253  word2vec  word2vec_0.40      0.40
# 3    0.773202       Boring      -0.008339  word2vec  word2vec_0.50      0.50
# 4    0.809106       Boring      -0.010943  word2vec  word2vec_0.60      0.60
# 5    0.857932       Boring      -0.014136  word2vec  word2vec_0.70      0.70
# 6    0.849934       Boring      -0.013203  word2vec  word2vec_0.80      0.80
# 7    0.830987       Boring      -0.012881  word2vec  word2vec_0.90      0.90
# 8    0.309675     Exciting      -0.000102  word2vec  word2vec_0.20      0.20
# 9    0.389885     Exciting      -0.000776  word2vec  word2vec_0.30      0.30
# 10   0.749868     Exciting      -0.003179  word2vec  word2vec_0.40      0.40
# 11   0.737692     Exciting      -0.005971  word2vec  word2vec_0.50      0.50
# 12   0.821571     Exciting      -0.009656  word2vec  word2vec_0.60      0.60
# 13   0.804056     Exciting      -0.009538  word2vec  word2vec_0.70      0.70
# 14   0.768849     Exciting      -0.008663  word2vec  word2vec_0.80      0.80
# 15   0.744058     Exciting      -0.008670  word2vec  word2vec_0.90      0.90
# 16   0.288769     NewAtEnd      -0.000195  word2vec  word2vec_0.20      0.20
# 17   0.400057     NewAtEnd      -0.000548  word2vec  word2vec_0.30      0.30
# 18   0.580485     NewAtEnd      -0.002025  word2vec  word2vec_0.40      0.40
# 19   0.653408     NewAtEnd      -0.004425  word2vec  word2vec_0.50      0.50
# 20   0.649366     NewAtEnd      -0.005529  word2vec  word2vec_0.60      0.60
# 21   0.531245     NewAtEnd      -0.006437  word2vec  word2vec_0.70      0.70
# 22   0.500878     NewAtEnd      -0.006302  word2vec  word2vec_0.80      0.80
# 23   0.493997     NewAtEnd      -0.006417  word2vec  word2vec_0.90      0.90
# 24   0.544288       Normal      -0.000117  word2vec  word2vec_0.20      0.20
# 25   0.675250       Normal      -0.002917  word2vec  word2vec_0.30      0.30
# 26   0.824265       Normal      -0.005806  word2vec  word2vec_0.40      0.40
# 27   0.835769       Normal      -0.007743  word2vec  word2vec_0.50      0.50
# 28   0.895176       Normal      -0.012038  word2vec  word2vec_0.60      0.60
# 29   0.857670       Normal      -0.013838  word2vec  word2vec_0.70      0.70
# 30   0.832479       Normal      -0.012426  word2vec  word2vec_0.80      0.80
# 31   0.801174       Normal      -0.012387  word2vec  word2vec_0.90      0.90
# 32   0.607932  SuperBoring      -0.000950  word2vec  word2vec_0.20      0.20
# 33   0.425120  SuperBoring      -0.000676  word2vec  word2vec_0.30      0.30
# 34   0.773815  SuperBoring      -0.002711  word2vec  word2vec_0.40      0.40
# 35   0.884038  SuperBoring      -0.003656  word2vec  word2vec_0.50      0.50
# 36   0.921278  SuperBoring      -0.009270  word2vec  word2vec_0.60      0.60
# 37   0.905126  SuperBoring      -0.010938  word2vec  word2vec_0.70      0.70
# 38   0.872126  SuperBoring      -0.010399  word2vec  word2vec_0.80      0.80
# 39   0.878599  SuperBoring      -0.010680  word2vec  word2vec_0.90      0.90

# %%
evaluation.to_excel("Data Output/ParamSearch_Experiment_evaluation_2.xlsx")

# %%
evaluation.to_csv("Data Output/ParamSearch_Experiment_evaluation_2.csv")

# %%
for dataset, datasetData in evaluation.groupby("dataset"):
    datasetData.sort_values(by="decline_slope", ascending=False, inplace=True)
    print datasetData.head()
# Out:
#    corr_true dataset  decline_slope    method            run threshold
# 0   0.549540  Boring      -0.001116  word2vec  word2vec_0.20      0.20
# 1   0.688933  Boring      -0.003030  word2vec  word2vec_0.30      0.30
# 2   0.872242  Boring      -0.006253  word2vec  word2vec_0.40      0.40
# 3   0.773202  Boring      -0.008339  word2vec  word2vec_0.50      0.50
# 4   0.809106  Boring      -0.010943  word2vec  word2vec_0.60      0.60
#     corr_true   dataset  decline_slope    method            run threshold
# 8    0.309675  Exciting      -0.000102  word2vec  word2vec_0.20      0.20
# 9    0.389885  Exciting      -0.000776  word2vec  word2vec_0.30      0.30
# 10   0.749868  Exciting      -0.003179  word2vec  word2vec_0.40      0.40
# 11   0.737692  Exciting      -0.005971  word2vec  word2vec_0.50      0.50
# 14   0.768849  Exciting      -0.008663  word2vec  word2vec_0.80      0.80
#     corr_true   dataset  decline_slope    method            run threshold
# 16   0.288769  NewAtEnd      -0.000195  word2vec  word2vec_0.20      0.20
# 17   0.400057  NewAtEnd      -0.000548  word2vec  word2vec_0.30      0.30
# 18   0.580485  NewAtEnd      -0.002025  word2vec  word2vec_0.40      0.40
# 19   0.653408  NewAtEnd      -0.004425  word2vec  word2vec_0.50      0.50
# 20   0.649366  NewAtEnd      -0.005529  word2vec  word2vec_0.60      0.60
#     corr_true dataset  decline_slope    method            run threshold
# 24   0.544288  Normal      -0.000117  word2vec  word2vec_0.20      0.20
# 25   0.675250  Normal      -0.002917  word2vec  word2vec_0.30      0.30
# 26   0.824265  Normal      -0.005806  word2vec  word2vec_0.40      0.40
# 27   0.835769  Normal      -0.007743  word2vec  word2vec_0.50      0.50
# 28   0.895176  Normal      -0.012038  word2vec  word2vec_0.60      0.60
#     corr_true      dataset  decline_slope    method            run threshold
# 33   0.425120  SuperBoring      -0.000676  word2vec  word2vec_0.30      0.30
# 32   0.607932  SuperBoring      -0.000950  word2vec  word2vec_0.20      0.20
# 34   0.773815  SuperBoring      -0.002711  word2vec  word2vec_0.40      0.40
# 35   0.884038  SuperBoring      -0.003656  word2vec  word2vec_0.50      0.50
# 36   0.921278  SuperBoring      -0.009270  word2vec  word2vec_0.60      0.60
# /Users/jchan/anaconda/lib/python2.7/site-packages/IPython/kernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from IPython.kernel.zmq import kernelapp as app

# %% [markdown]
# # TODO
# 1. Compute exponent: transform GT_predict to log scale and then compute slope
# 2. Also get normal slope
# 3. Maybe compute percent change

# %%
# log-transform GT-predict for plotting on logarithmic scale and exponential slope estimation
data['GT_predict_log'] = np.log10(data['GT_predict'])

# %%
data.GT_predict_log
# Out:
# 0      -1.040959
# 1      -1.173925
# 2      -1.040959
# 3      -1.065502
# 4      -1.431798
# 5      -1.455932
# 6      -1.481486
# 7      -1.522879
# 8      -1.552842
# 9      -1.522879
# 10     -1.795880
# 11     -1.769551
# 12     -1.769551
# 13     -1.744727
# 14     -1.657577
# 15     -1.744727
# 16     -1.677781
# 17     -1.721246
# 18     -1.721246
# 19     -1.698970
# 20     -1.721246
# 21     -1.721246
# 22     -1.744727
# 23     -1.769551
# 24     -1.769551
# 25     -1.795880
# 26     -1.795880
# 27     -1.744727
# 28     -1.698970
# 29     -1.721246
#           ...
# 1770   -0.351640
# 1771   -0.364516
# 1772   -0.371611
# 1773   -0.371611
# 1774   -0.378824
# 1775   -0.374688
# 1776   -0.392545
# 1777   -0.392545
# 1778   -0.401209
# 1779   -0.392545
# 1780   -0.402305
# 1781   -0.408935
# 1782   -0.417937
# 1783   -0.422508
# 1784   -0.424812
# 1785   -0.437707
# 1786   -0.447332
# 1787   -0.449772
# 1788   -0.458421
# 1789   -0.488117
# 1790   -0.488117
# 1791   -0.489455
# 1792   -0.492144
# 1793   -0.498941
# 1794   -0.511449
# 1795   -0.517126
# 1796   -0.514279
# 1797   -0.515700
# 1798   -0.505845
# 1799   -0.519993
# Name: GT_predict_log, dtype: float64

# %%
data.to_csv("Data Output/Word2VecOnlyWithStemming_withlog.csv")
