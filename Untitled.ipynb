# %%
import csv
import json
import pandas as pd

# %%
data = pd.read_csv("Input/ideas_fabric_display_with_ratings.csv");
print data
# Out:
#       Unnamed: 0  Unnamed: 0.1         cond    id  project_slug  \
# 0              0             0    on-demand   139  timing_task2
# 1              1             1    on-demand   142  timing_task2
# 2              2             2         none   143  timing_task2
# 3              3             3    on-demand   144  timing_task2
# 4              4             4         none   145  timing_task2
# 5              5             5    on-demand   146  timing_task2
# 6              6             6         idle   147  timing_task2
# 7              7             7    on-demand   148  timing_task2
# 8              8             8         none   149  timing_task2
# 9              9             9    on-demand   150  timing_task2
# 10            10            10         idle   151  timing_task2
# 11            11            11         none   152  timing_task2
# 12            12            12    on-demand   153  timing_task2
# 13            13            13         idle   154  timing_task2
# ...

# %%
import csv
import json

csvfile = open('Data Output/Experiment/ideas_fabric_display_with_ratings_results.csv', 'rU')
jsonfile = open('output.json', 'w')

fieldnames = ("authorID", "method", "timeSlice", "GT_predict", "new_TRUE")
reader = csv.DictReader( csvfile, fieldnames)
for row in reader:
    json.dump(row, jsonfile)
    jsonfile.write('\n')

# %%
# Out:
# False
